# %%
import pandas as pd

df = pd.read_csv('../data/fake_job_postings.csv')
print("Shape:", df.shape)
print("\nColumn names:")
print(df.columns.tolist())
# Out:
# Shape: (17880, 18)
#
# Column names:
# ['job_id', 'title', 'location', 'department', 'salary_range', 'company_profile', 'description', 'requirements', 'benefits', 'telecommuting', 'has_company_logo', 'has_questions', 'employment_type', 'required_experience', 'required_education', 'industry', 'function', 'fraudulent']

# %%
print("Fake vs Real count:")
print(df['fraudulent'].value_counts())

print("\nIn percentage:")
print((df['fraudulent'].value_counts(normalize=True) * 100).round(2))
# Out:
# Fake vs Real count:
# fraudulent
# 0    17014
# 1      866
# Name: count, dtype: int64
#
# In percentage:
# fraudulent
# 0    95.16
# 1     4.84
# Name: proportion, dtype: float64

# %%
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# job_id                     0
# title                      0
# location                 346
# department             11547
# salary_range           15012
# company_profile         3308
# description                1
# requirements            2696
# benefits                7212
# telecommuting              0
# has_company_logo           0
# has_questions              0
# employment_type         3471
# required_experience     7050
# required_education      8105
# industry                4903
# function                6455
# fraudulent                 0
# dtype: int64

# %%
fake = df[df['fraudulent'] == 1][['title','description','requirements']].head(5)

for i, row in fake.iterrows():
    print("=" * 60)
    print("TITLE:", row['title'])
    print("\nDESC:", str(row['description'])[:400])
    print("\nREQ:", str(row['requirements'])[:200])
    print()
# Out:
# ...
# TITLE: IC&E Technician
#
# DESC: IC&amp;E Technician | Bakersfield, CA Mt. PosoPrincipal Duties and Responsibilities: Calibrates, tests, maintains, troubleshoots, and installs all power plant instrumentation, control systems and electrical equipment.Performs maintenance on motor control centers, motor operated valves, generators, excitation equipment and motors.Performs preventive, predictive and corrective maintenance on equipme
#
# REQ: QualificationsKnowledge, Skills &amp; Abilities: A high school diploma or GED is required. Must have a valid driver’s license. Ability to read, write, and communicate effectively in English.  Good mat
#
# ...
# TITLE: Forward Cap.
#
# ...

# %%
real = df[df['fraudulent'] == 0][['title','description']].head(3)

for i, row in real.iterrows():
    print("=" * 60)
    print("TITLE:", row['title'])
    print("\nDESC:", str(row['description'])[:400])
    print()
# Out:
# ...
# TITLE: Marketing Intern
#
# DESC: Food52, a fast-growing, James Beard Award-winning online food community and crowd-sourced and curated recipe hub, is currently interviewing full- and part-time unpaid interns to work in a small team of editors, executives, and developers in its New York City headquarters.Reproducing and/or repackaging existing Food52 content for a number of partner sites, such as Huffington Post, Yahoo, Buzzfeed,
#
# ...
# TITLE: Customer Service - Cloud Video Production
#
# DESC: Organised - Focused - Vibrant - Awesome!Do you have a passion for customer service? Slick typing skills? Maybe Account Management? ...And think administration is cooler than a polar bear on a jetski? Then we need to hear you! We are the Cloud Video Production Service and opperating on a glodal level. Yeah, it's pretty cool. Serious about delivering a world class product and excellent customer serv
#
# ...
# TITLE: Commissioning Machinery Assistant (CMA)
#
# ...

# %%
import sys
sys.path.append('..')  # this lets notebook find your utils folder

from utils.preprocess import clean_text, combine_and_clean
import pandas as pd

df = pd.read_csv('../data/fake_job_postings.csv')

# Test clean_text on one example
sample = "We are URGENTLY hiring!! No experience needed. Visit http://scam.com now!!!"
print("Before cleaning:")
print(sample)
print("\nAfter cleaning:")
print(clean_text(sample))
# Out:
# Before cleaning:
# We are URGENTLY hiring!! No experience needed. Visit http://scam.com now!!!
#
# After cleaning:
# urgently hiring experience needed visit

# %%
# Now test on the full dataset
df = combine_and_clean(df)

print("Sample cleaned text from dataset:")
print(df['cleaned_text'].iloc[0])
print("\nAnother sample:")
print(df['cleaned_text'].iloc[100])
# Out:
# Sample cleaned text from dataset:
# ...
